# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()

path_to_csv = "./pa0(train-only).csv"
rawDF = pd.read_csv("pa0(train-only).csv")
# read and view head of csv file for quick check

# %%
formattedDF = rawDF.drop(['id'], axis = 1)
formattedDF.head()
# Out:
#         date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   7/9/2014         4       2.50         2720     10006     2.0           0
# 1  7/18/2014         2       2.50         2600      5000     1.0           0
# 2   7/7/2014         5       1.75         1650      3000     1.5           0
# 3  4/28/2015         4       1.75         1720      9600     1.0           0
# 4   9/4/2014         6       2.25         3830     11180     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      9        2720              0      1989             0
# 1     0          5      8        1300           1300      1926             0
# 2     0          3      8        1650              0      1902             0
# 3     0          4      8        1720              0      1969             0
# 4     2          5      9        2440           1390      1962             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15   price
# 0    98074  47.6295 -122.042           2720       10759  5.9495
# 1    98126  47.5806 -122.379           2260        5000  6.6500
# 2    98144  47.5955 -122.306           1740        4000  4.4300
# 3    98059  47.4764 -122.155           1660       10720  3.8000
# 4    98008  47.5849 -122.113           2500       10400  8.8700

# %%
dateformat = formattedDF["date"].str.split("/", expand = True)
formattedDF["year"] = dateformat[2]
formattedDF["month"] = dateformat[0]
formattedDF["day"] = dateformat[1]
formattedDF = formattedDF.drop(['date'], axis = 1)
formattedDF.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         4       2.50         2720     10006     2.0           0     0
# 1         2       2.50         2600      5000     1.0           0     0
# 2         5       1.75         1650      3000     1.5           0     0
# 3         4       1.75         1720      9600     1.0           0     0
# 4         6       2.25         3830     11180     1.0           0     2
#
#    condition  grade  sqft_above  ...  yr_renovated  zipcode      lat     long  \
# 0          3      9        2720  ...             0    98074  47.6295 -122.042
# 1          5      8        1300  ...             0    98126  47.5806 -122.379
# 2          3      8        1650  ...             0    98144  47.5955 -122.306
# 3          4      8        1720  ...             0    98059  47.4764 -122.155
# 4          5      9        2440  ...             0    98008  47.5849 -122.113
#
#    sqft_living15  sqft_lot15   price  year  month day
# 0           2720       10759  5.9495  2014      7   9
# 1           2260        5000  6.6500  2014      7  18
# 2           1740        4000  4.4300  2014      7   7
# 3           1660       10720  3.8000  2015      4  28
# 4           2500       10400  8.8700  2014      9   4
#
# [5 rows x 22 columns]

# %%
formattedDF['bedrooms'].unique()
# Out:
# array([ 4,  2,  5,  6,  3,  1,  7, 10,  9,  8, 33, 11])

# %%
f, ax = plt.subplots(figsize=(15, 12))
sns.boxplot(x="bedrooms", y="price", data=formattedDF, flierprops = dict(markerfacecolor = '0.50', markersize = 1))

# %%
plt.subplots(figsize=(15, 12))
sns.boxplot(x="bathrooms", y="price", data=formattedDF, flierprops = dict(markerfacecolor = '0.50', markersize = 1))

# %%
plt.subplots(figsize=(15, 12))
sns.boxplot(x="floors", y="price", data=formattedDF, flierprops = dict(markerfacecolor = '0.50', markersize = 1))
# Out:
# <AxesSubplot:xlabel='floors', ylabel='price'>

# %%
covariance_matrix = finalDF[['sqft_living','sqft_lot','sqft_living15','sqft_lot15']].cov()
covariance_matrix

plt.title("sqft_living15 vs sqft_living")
sns.relplot(x="sqft_living", y="sqft_living15", data=formattedDF)
plt.savefig("Q4P1.png", format="png")

plt.title("sqft_lot15 vs sqft_lot")
sns.relplot(x="sqft_lot", y="sqft_lot15", data=formattedDF)
plt.savefig("Q4P2.png", format="png")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('sqft_living', 'sqft_lot')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-7a2c2ea24b96> in <module>
# ----> 1 formattedDF["sqft_living", "sqft_lot"]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: ('sqft_living', 'sqft_lot')
